# %%
# Separate into 10 time intervals (archived hard code very bad do not use, use the function separate_into_intervals instead)
input_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6Class\helical_1"
output_folder1 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\first_tenth"
output_folder2 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\second_tenth"
output_folder3 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\third_tenth"
output_folder4 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\fourth_tenth"
output_folder5 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\fifth_tenth"
output_folder6 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\sixth_tenth"
output_folder7 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\seventh_tenth"
output_folder8 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\eighth_tenth"
output_folder9 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\ninth_tenth"
output_folder10 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\last_tenth"

# Ensure the output folder exists, create it if necessary
os.makedirs(output_folder1, exist_ok=True)
os.makedirs(output_folder2, exist_ok=True)
os.makedirs(output_folder3, exist_ok=True)
os.makedirs(output_folder4, exist_ok=True)
os.makedirs(output_folder5, exist_ok=True)
os.makedirs(output_folder6, exist_ok=True)
os.makedirs(output_folder7, exist_ok=True)
os.makedirs(output_folder8, exist_ok=True)
os.makedirs(output_folder9, exist_ok=True)
os.makedirs(output_folder10, exist_ok=True)

# Loop through files in the input folder
for filename in os.listdir(input_folder):
    try:
        t_number = int(filename.split("t-")[1].split("_")[0])
        # Check if the number is between x and y (inclusive)
        if 1 <= t_number <= 20:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder1, filename)
            shutil.copy(input_filepath, output_filepath)
        if 21 <= t_number <= 40:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder2, filename)
            shutil.copy(input_filepath, output_filepath)
        if 41 <= t_number <= 60:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder3, filename)
            shutil.copy(input_filepath, output_filepath)
        if 61 <= t_number <= 80:
            # Build the full paths for input and output files
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder4, filename)
            # Copy the file to the output folder
            shutil.copy(input_filepath, output_filepath)
        if 81 <= t_number <= 100:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder5, filename)
            shutil.copy(input_filepath, output_filepath)
        if 101 <= t_number <= 120:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder6, filename)
            shutil.copy(input_filepath, output_filepath)
        if 121 <= t_number <= 140:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder7, filename)
            shutil.copy(input_filepath, output_filepath)
        if 141 <= t_number <= 160:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder8, filename)
            shutil.copy(input_filepath, output_filepath)
        if 161 <= t_number <= 180:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder9, filename)
            shutil.copy(input_filepath, output_filepath)
        if 181 <= t_number <= 200:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder10, filename)
            shutil.copy(input_filepath, output_filepath)
    except (ValueError, IndexError):
        # Handle cases where extraction or conversion fails
        pass

# Print a message indicating the process is complete
print("Extraction and copy completed.")

# %%
# Data standardisation
import random
import os
import shutil

input_folder = r'C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\Outputs_Grayscale_Labelled_Images_Sizes\size_folder'
output_folder_train = r'C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\dataSelectorHelical'
# output_folder_test =
# output_folder_val =

# Ensure the output folder exists, create it if necessary
os.makedirs(output_folder_train, exist_ok=True)
# os.makedirs(output_folder_test, exist_ok=True)
# os.makedirs(output_folder_val, exist_ok=True)


# define the paramaters for standardization
# the number of contours desired for each bin size
num_contours = {}
#lower limit of size range
lower_size = 5
#upperlimit of size range
upper_size = 14.5
# size of binwidth
bin_width = 0.5
# number of input images
input_num = 4



last_time_section = ((input_num-1)/(input_num))*200
num_bins = int((upper_size-lower_size)/bin_width)
# print(random.shuffle(os.listdir(input_folder))) this does not work for some reason
# this loops through every single image, faster to loop through each bin size 
for filename in os.listdir(input_folder):
    size = float(filename[-17:-5])
    t_number = int(filename.split("t-")[1].split("_")[0])
    if t_number > last_time_section:
        for i in range(num_bins):
            if lower_size + i * bin_width <= size <= lower_size + (i+1) * bin_width:
                if counter <= num_contours:
                    # print(counter)
                    input_filepath = os.path.join(input_folder, filename)
                    output_filepath = os.path.join(output_folder_train, filename)
                    shutil.copy(input_filepath, output_filepath)
                    counterDict{i}
                    # print(counter)
                    # print("pao sucked my cock")
                    for j in range(input_num-1):
                        fig_number = filename.split("_")[1]
                        # print(fig_number)
                        t_number_new = str(int(t_number-(j+1)*(200/input_num)))
                        # print(t_number_new)
                        # print(f"Fig_{fig_number}__t-{t_number_new}")
                        filename_new = [item for item in os.listdir(input_folder) if item.startswith(f"Fig_{fig_number}__t-{t_number_new}")][0]
                        # print(filename_new)
                        input_filepath = os.path.join(input_folder, filename_new)
                        output_filepath = os.path.join(output_folder_train, filename_new)
                        shutil.copy(input_filepath, output_filepath)
# Out:
#   Cell In[1], line 46
#     counterDict{i}
#                ^
# SyntaxError: invalid syntax

# %%
# Split input folder into 5 quarters

# Specify the input and output folders
input_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6Class\helical_1"
output_folder1 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\first_fifth"
output_folder2 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\second_fifth"
output_folder3 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\third_fifth"
output_folder4 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\fourth_fifth"
output_folder5 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassHelical_1\fifth_fifth"

# Ensure the output folder exists, create it if necessary
os.makedirs(output_folder1, exist_ok=True)
os.makedirs(output_folder2, exist_ok=True)
os.makedirs(output_folder3, exist_ok=True)
os.makedirs(output_folder4, exist_ok=True)
os.makedirs(output_folder5, exist_ok=True)

# Loop through files in the input folder
for filename in os.listdir(input_folder):
    try:
        t_number = int(filename.split("t-")[1].split("_")[0])
        # Check if the number is between x and y (inclusive)
        if 1 <= t_number <= 40:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder1, filename)
            shutil.copy(input_filepath, output_filepath)
        if 41 <= t_number <= 80:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder2, filename)
            shutil.copy(input_filepath, output_filepath)
        if 81 <= t_number <= 120:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder3, filename)
            shutil.copy(input_filepath, output_filepath)
        if 121 <= t_number <= 160:
            # Build the full paths for input and output files
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder4, filename)
            # Copy the file to the output folder
            shutil.copy(input_filepath, output_filepath)
        if 161 <= t_number <= 200:
            # Build the full paths for input and output files
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder5, filename)
            # Copy the file to the output folder
            shutil.copy(input_filepath, output_filepath)
    except (ValueError, IndexError):
        # Handle cases where extraction or conversion fails
        pass

# Print a message indicating the process is complete
print("Extraction and copy completed.")

# %%
# Split input folder into 4 quarters

# Specify the input and output folders
# input_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00MultiConc\Outputs_Grayscale_Labelled_Images_Sizes"
input_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00MultiConc\Outputs_Grayscale_Labelled_Images_Sizes\full_folder"
# input_folder = r"C:\Users\Public\PartIIB project 2023_2024\PastData\MultiConcHelical_size"
# output_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00MultiConc\Outputs_Grayscale_Labelled_Images_Sizes\full_folder"
output_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00MultiConc\Outputs_Grayscale_Labelled_Images_Sizes\full_folder\fourth_quarter"
# output_folder = r"C:\Users\Public\PartIIB project 2023_2024\PastData\MultiConcHelical_size\first_quarter"
# Ensure the output folder exists, create it if necessary
os.makedirs(output_folder, exist_ok=True)

# Loop through files in the input folder
for filename in os.listdir(input_folder):
    # Check if the file name contains the desired pattern
    if "t-" in filename:
        # Extract the number after "t-"
        try:
            t_number = int(filename.split("t-")[1].split("_")[0])
            # Check if the number is between x and y (inclusive)
            if 151 <= t_number <= 200:
                # Build the full paths for input and output files
                input_filepath = os.path.join(input_folder, filename)
                output_filepath = os.path.join(output_folder, filename)
                # Copy the file to the output folder
                shutil.copy2(input_filepath, output_filepath)
        except (ValueError, IndexError):
            # Handle cases where extraction or conversion fails
            pass

# Print a message indicating the process is complete
print("Extraction and copy completed.")

# %%
# Split input folder into 4 quarters

# Specify the input and output folders
input_folder = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassSTD\helical_2"
output_folder1 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassSTD\helical_2\first_quarter"
output_folder2 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassSTD\helical_2\second_quarter"
output_folder3 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassSTD\helical_2\third_quarter"
output_folder4 = r"C:\Users\Public\PartIIB project 2023_2024\Image collection without reaction\00AgNO3_mole_fraction\6ClassSTD\helical_2\fourth_quarter"

# Ensure the output folder exists, create it if necessary
os.makedirs(output_folder1, exist_ok=True)
os.makedirs(output_folder2, exist_ok=True)
os.makedirs(output_folder3, exist_ok=True)
os.makedirs(output_folder4, exist_ok=True)

# Loop through files in the input folder
for filename in os.listdir(input_folder):
    try:
        t_number = int(filename.split("t-")[1].split("_")[0])
        # Check if the number is between x and y (inclusive)
        if 1 <= t_number <= 50:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder1, filename)
            shutil.copy(input_filepath, output_filepath)
        if 51 <= t_number <= 100:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder2, filename)
            shutil.copy(input_filepath, output_filepath)
        if 101 <= t_number <= 150:
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder3, filename)
            shutil.copy(input_filepath, output_filepath)
        if 151 <= t_number <= 200:
            # Build the full paths for input and output files
            input_filepath = os.path.join(input_folder, filename)
            output_filepath = os.path.join(output_folder4, filename)
            # Copy the file to the output folder
            shutil.copy(input_filepath, output_filepath)
    except (ValueError, IndexError):
        # Handle cases where extraction or conversion fails
        pass

# Print a message indicating the process is complete
print("Extraction and copy completed.")
